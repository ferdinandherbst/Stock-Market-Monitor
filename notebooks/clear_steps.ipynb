# %% [markdown]
# # Correlation of different asset classes

# %% [markdown]
# libraries

# %%
import yfinance as yfinance
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Data Extraction with ```yfinance```

# %%
# tickers solo
gold_ticker = "GC=F"
bitcoin_ticker = "BTC-USD"
nasdaq_ticker = "^IXIC"
sp_500_ticker = "@ES"

# tickers together
tickers = {
    "Bitcoin": "BTC-USD",
    "Gold": "GC=F",
    "Nasdaq": "^IXIC",
    "S&P500": "@ES"
}

# %%
data = yfinance.download(list(tickers.values()), start="2019-01-01")['Adj Close']
data

# %% [markdown]
# # Data Cleaning with ```pandas```

# %% [markdown]
# # Data Analysis with ```numpy```

# %% [markdown]
# # Data Visualization with ```matplotlib```
